# %% [markdown]
# # Q1. Create a function that takes two numbers as parameters and returns their addition.

# %%
# Function to add two numbers

def addition(num1, num2):
    return num1 + num2

result = addition(10, 5)
print("Addition =", result)
# Out:
# Addition = 15

# %% [markdown]
# #Q2. Write a function that takes a student name and marks as arguments and prints whether the student passed or failed.

# %%
# Function to check pass or fail

def student_result(name, marks):
    if marks >= 50:
        print(name, "passed")
    else:
        print(name, "failed")

student_result("Ali", 75)
student_result("Sara", 40)
# Out:
# Ali passed
# Sara failed

# %% [markdown]
# #Q3. Create a function that accepts a list of numbers and returns the largest number from the list.

# %%
# Function to find the largest number in a list

def largest_number(numbers):
    return max(numbers)
list1 = [10, 45, 67, 23]

print("Largest number =", largest_number(list1))
# Out:
# Largest number = 67

# %% [markdown]
# #Q4. Write a function that takes a string as input and counts the number of vowels in it.

# %%
# Function to count vowels in a string

def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0

    for i in text:
        if i in vowels:
            count += 1

    return count

print(count_vowels("Python Programming"))
# Out:
# 4

# %% [markdown]
# # Q5. Create a shopping bill function that takes:
# • Item name
# • Item price
# • Quantity
# And returns the total bill.

# %%
# Shopping bill function

def shopping_bill(item_name, item_price, quantity):
    total_bill = item_price * quantity
    return total_bill

# Example
bill = shopping_bill("Shoes", 2500, 2)

print("Total Bill =", bill)
# Out:
# Total Bill = 5000

# %% [markdown]
# # Q6. Write a lambda function to calculate the square of a number.

# %%
# Lambda function to calculate square

square = lambda x: x * x

# Example
print(square(5))
# Out:
# 25

# %% [markdown]
# # Q7. Create a lambda function that checks whether a number is:
# • Even
# • Odd
# Using if-else inside lambda.

# %%
# Lambda function to check even or odd

check = lambda x: "Even" if x % 2 == 0 else "Odd"

# Example
print(check(8))
print(check(7))
# Out:
# Even
# Odd

# %% [markdown]
# #Q8. Banking System

# %%
# Simple Banking System

balance = 5000  # initial balance

def deposit(amount):
    global balance
    balance += amount
    print("Deposited:", amount)

def withdraw(amount):
    global balance
    if amount <= balance:
        balance -= amount
        print("Withdrawn:", amount)
    else:
        print("Insufficient balance")

def check_balance():
    print("Current Balance:", balance)


while True:
    print("\n1. Deposit")
    print("2. Withdraw")
    print("3. Check Balance")
    print("4. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        amt = int(input("Enter amount: "))
        deposit(amt)

    elif choice == "2":
        amt = int(input("Enter amount: "))
        withdraw(amt)

    elif choice == "3":
        check_balance()

    elif choice == "4":
        break

    else:
        print("Invalid choice")
# Out:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter choice: 2
# Enter amount: 30000
# Insufficient balance
#
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Exit
# Enter choice: 4

# %% [markdown]
# ##Q9. Product Management System

# %%
# Product Management System
# Dictionary to store products
products = {}

# Add product
def add_product():
    name = input("Enter product name: ")
    price = int(input("Enter price: "))
    products[name] = price
    print("Product added")

# Remove product
def remove_product():
    name = input("Enter product name to remove: ")
    if name in products:   # condition
        del products[name]
        print("Product removed")
    else:
        print("Product not found")

# Display products
def display_products():
    print("\nProducts:")
    for name, price in products.items():   # loop
        print(name, ":", price)

# Calculate total price
def total_price():
    total = 0
    for price in products.values():   # loop + operator
        total += price
    print("Total Price =", total)

# Main loop
while True:
    print("\n1-Add  2-Remove  3-Display  4-Total  5-Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        add_product()

    elif choice == "2":
        remove_product()

    elif choice == "3":
        display_products()

    elif choice == "4":
        total_price()

    elif choice == "5":
        break

    else:
        print("Invalid choice")
# Out:
# 1-Add  2-Remove  3-Display  4-Total  5-Exit
# Enter choice: 1
# Enter product name: Apple
# Enter price: 50
# Product added
#
# 1-Add  2-Remove  3-Display  4-Total  5-Exit
# Enter choice: 5
